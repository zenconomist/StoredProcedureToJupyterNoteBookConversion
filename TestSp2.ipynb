-- %% [markdown]
--  ### Step 1: Create a Common Table Expression (CTE)

-- %%
        SELECT            Column1,            Column2,            Column3        FROM            SomeTable Where Column1 = 'example'

-- %%
        SELECT            Column1,            Column2,            Column3        FROM            SomeTable Where Column1 = 'example'

-- %% [markdown]
--  ### Step 2: Insert data into a temporary tablethis temp table will be used in the final SELECT

-- %%
                SELECT        Column1,        Column2,        Column3            INTO #TempTable        FROM            cte_example

-- %% [markdown]
--  ### Step 3: Perform a final SELECTthis is a line below a BlocComthis is a second line below a BlocCom

-- %%
    SELECT        Column1,        Column2,        SUM(Column3) AS TotalColumn3    FROM        #TempTable WHERE TotalColumn3 > 1000    GROUP BY        Column1,        Column2

-- %% [markdown]
--  #### CTE example where 2 CTEs are used and a final SELECT is performedThis is a second line of BlocCom

-- %%
            /*                This is a comment for the CTE            */    ;WITH cte_example AS (        SELECT            Column1,            Column2,            Column3        FROM            SomeTable WHERE Column1 = 'example'    )        SELECT            Column1,            Column2,            Column3        FROM            SomeTable WHERE Column1 = 'example2'

-- %%
            /*                This is a comment for the CTE            */    ;WITH cte_example AS (        SELECT            Column1,            Column2,            Column3        FROM            SomeTable WHERE Column1 = 'example'    )        SELECT            Column1,            Column2,            Column3        FROM            SomeTable WHERE Column1 = 'example2'

-- %%
        SELECT            Column1,            Column2,            Column3        FROM            SomeTable WHERE Column1 = 'example2'

-- %%
    ;With a as (        select 1 as a, 2 as b

-- %%
        select 1 as a, 2 as b

-- %%
        select 1 as a, 2 as b
